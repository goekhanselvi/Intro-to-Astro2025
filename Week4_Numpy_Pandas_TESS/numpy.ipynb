# %% [markdown]
# # Python Libraries 1
# # Numpy ![numpy.png](attachment:numpy.png)

# %%
import numpy

# %%
l=[1,2,3]
arr=numpy.array(l)

# %%
arr
# Out:
# array([1, 2, 3])

# %%
import numpy as np

# %%
np.array(l)
# Out:
# array([1, 2, 3])

# %%
arr_1=np.array([1,2,3])

# %%
arr_1
# Out:
# array([1, 2, 3])

# %%
arr_1+1
# Out:
# array([2, 3, 4])

# %%
arr_1*2
# Out:
# array([2, 4, 6])

# %%
l_1=[1,2,3]
l_2=[2,3,4]
l_1+l_2
# Out:
# [1, 2, 3, 2, 3, 4]

# %%
arr_1=np.array(l_1)
arr_2=np.array(l_2)

# %%
arr_1+arr_2
# Out:
# array([3, 5, 7])

# %%
arr_1.sum()
# Out:
# 6

# %%
#Indexing
arr_1[0]
# Out:
# 1

# %%
arr_1[2]
# Out:
# 3

# %%
for i in arr_1:
    print(i)
# Out:
# 1
# 2
# 3

# %%
arr_2D=np.array([[1,1],[2,1],[3,2]])

# %%
arr_2D
# Out:
# array([[1, 1],
#        [2, 1],
#        [3, 2]])

# %%
rand_array=np.random.random(size=[3,2])

# %%
zero_array=np.zeros(shape=[3,2])
zero_array
# Out:
# array([[0., 0.],
#        [0., 0.],
#        [0., 0.]])

# %%
zero_array
# Out:
# array([[0., 0.],
#        [0., 0.],
#        [0., 0.]])

# %%
rand_array=np.random.random(size=[5,5])

# %%
rand_array
# Out:
# array([[0.05665963, 0.95371557, 0.67741833, 0.13890977, 0.56926989],
#        [0.25380594, 0.45314622, 0.99441836, 0.2257251 , 0.10646226],
#        [0.97177829, 0.89923864, 0.04353039, 0.13140804, 0.1879999 ],
#        [0.37310563, 0.26823545, 0.15879747, 0.53504517, 0.74090516],
#        [0.83460562, 0.86785199, 0.21792472, 0.79892757, 0.12830686]])

# %%
rand_array[1,1]
# Out:
# 0.453146218167104

# %%
rand_array[0:2,0:2]
# Out:
# array([[0.05665963, 0.95371557],
#        [0.25380594, 0.45314622]])

# %%
rand_array.sum(axis=1)
# Out:
# array([2.39597318, 2.03355787, 2.23395526, 2.07608888, 2.84761676])

# %%
np.array([0.4924862 , 0.58400964, 0.42182289, 0.31476085, 0.26750594]).sum()
# Out:
# 2.08058552

# %%
rand_array*10
# Out:
# array([[0.56659628, 9.53715571, 6.77418327, 1.3890977 , 5.69269889],
#        [2.53805937, 4.53146218, 9.94418358, 2.25725095, 1.06462261],
#        [9.71778289, 8.99238639, 0.4353039 , 1.3140804 , 1.87999899],
#        [3.73105633, 2.6823545 , 1.58797467, 5.35045167, 7.40905164],
#        [8.34605624, 8.67851986, 2.17924717, 7.98927569, 1.28306865]])

# %%
rand_array
# Out:
# array([[0.05665963, 0.95371557, 0.67741833, 0.13890977, 0.56926989],
#        [0.25380594, 0.45314622, 0.99441836, 0.2257251 , 0.10646226],
#        [0.97177829, 0.89923864, 0.04353039, 0.13140804, 0.1879999 ],
#        [0.37310563, 0.26823545, 0.15879747, 0.53504517, 0.74090516],
#        [0.83460562, 0.86785199, 0.21792472, 0.79892757, 0.12830686]])

# %%
rand_array=np.random.random(size=100)

# %%
rand_array.sort()

# %%
rand_array
# Out:
# array([0.00581912, 0.00692598, 0.0118416 , 0.01187351, 0.03891794,
#        0.04910734, 0.06065637, 0.06092266, 0.06393884, 0.06703305,
#        0.06711882, 0.07682255, 0.08042209, 0.09809348, 0.09922342,
#        0.10554681, 0.11457173, 0.1323655 , 0.13817548, 0.14459018,
#        0.1539411 , 0.16025004, 0.16387826, 0.17052087, 0.18008731,
#        0.18077133, 0.18196939, 0.19372599, 0.20155124, 0.20327576,
#        0.20372731, 0.20655341, 0.21216908, 0.2163587 , 0.22334086,
#        0.22993284, 0.2324063 , 0.23401956, 0.23659966, 0.25214625,
#        0.25882733, 0.2650937 , 0.34656424, 0.34900442, 0.35952742,
#        0.39373205, 0.39500283, 0.42773229, 0.42995176, 0.43489095,
#        0.43525046, 0.45153165, 0.46764804, 0.48085994, 0.49855263,
#        0.52383383, 0.52642123, 0.52706565, 0.54260192, 0.56110155,
#        0.56746335, 0.5863651 , 0.58663811, 0.59255512, 0.62905555,
#        0.62967537, 0.64406569, 0.65453007, 0.6755442 , 0.68207264,
#        0.69388659, 0.70262581, 0.718359  , 0.73774241, 0.73810936,
#        0.74559048, 0.75892382, 0.76892606, 0.77464296, 0.77512741,
#        0.7869161 , 0.79603336, 0.80013289, 0.80079125, 0.80611017,
#        0.81411823, 0.8263926 , 0.84373905, 0.84645115, 0.86059203,
#        0.8612861 , 0.86236897, 0.87658044, 0.89718652, 0.90287405,
#        0.90529432, 0.95004996, 0.97734905, 0.98254641, 0.98863435])

# %%
for i in rand_array:
    print(i)
# Out:
# 0.0058191206545863405
# 0.00692598026424629
# 0.011841596262431864
# 0.01187350570642709
# 0.03891794033311646
# 0.049107337788314664
# 0.06065637308090366
# 0.06092266213587594
# 0.0639388408887831
# 0.06703304521324038
# 0.06711881627928296
# 0.07682255334722199
# 0.08042208669564666
# 0.09809347883223396
# 0.09922342003109785
# 0.1055468065449704
# 0.11457173123549247
# 0.13236550038209904
# 0.13817547615732817
# 0.14459017618875136
# 0.15394109503618236
# 0.16025003887531586
# 0.1638782571440629
# 0.17052086911465936
# 0.18008730746505786
# 0.1807713253424389
# 0.18196939418146563
# 0.19372599160465043
# 0.20155124352623444
# 0.20327575812701204
# 0.20372730979466702
# 0.2065534058649069
# 0.21216908023984116
# 0.21635870347976305
# 0.22334086284057308
# 0.22993283613047832
# 0.23240630311842703
# 0.23401956152664405
# 0.23659966282434308
# 0.25214624794606955
# 0.2588273281355602
# 0.26509369936461114
# 0.3465642435999621
# 0.34900441554860373
# 0.3595274173689499
# 0.3937320480555758
# 0.39500282735351844
# 0.4277322878316332
# 0.4299517551787263
# 0.4348909528195649
# 0.4352504552286999
# 0.45153164957607506
# 0.4676480433095589
# 0.48085993525487225
# 0.4985526340966572
# 0.5238338319719019
# 0.5264212303125012
# 0.5270656499588098
# 0.5426019229050497
# 0.5611015494562013
# 0.5674633455633818
# 0.5863651019241737
# 0.5866381121697881
# 0.5925551159999615
# 0.6290555536087652
# 0.6296753743223918
# 0.6440656931982784
# 0.654530074734155
# 0.6755442027244756
# 0.6820726431358363
# 0.6938865934258109
# 0.7026258076336964
# 0.7183589964062824
# 0.7377424099899571
# 0.7381093616159575
# 0.7455904841302954
# 0.758923824502229
# 0.7689260574673444
# 0.774642961383984
# 0.7751274066725257
# 0.7869160968149617
# 0.7960333593890412
# 0.8001328852689936
# 0.8007912467571314
# 0.8061101666790272
# 0.8141182250881273
# 0.8263925955260227
# 0.8437390516118851
# 0.8464511499181064
# 0.8605920280207556
# 0.86128609603746
# 0.8623689686469533
# 0.8765804412480908
# 0.8971865240827328
# 0.9028740475332263
# 0.9052943247629168
# 0.950049956897174
# 0.9773490459997196
# 0.982546414323208
# 0.9886343510613139

# %% [raw]
# for row in rand_array:
#     for i in row:
#         print(i)

# %%
# Exercises.

# %%
x=np.linspace(0,10,100)
x.sum()
# Out:
# 500.0

# %%
#Calculate y=7x+2
y=7*x+2
y
# Out:
# array([ 2.        ,  2.70707071,  3.41414141,  4.12121212,  4.82828283,
#         5.53535354,  6.24242424,  6.94949495,  7.65656566,  8.36363636,
#         9.07070707,  9.77777778, 10.48484848, 11.19191919, 11.8989899 ,
#        12.60606061, 13.31313131, 14.02020202, 14.72727273, 15.43434343,
#        16.14141414, 16.84848485, 17.55555556, 18.26262626, 18.96969697,
#        19.67676768, 20.38383838, 21.09090909, 21.7979798 , 22.50505051,
#        23.21212121, 23.91919192, 24.62626263, 25.33333333, 26.04040404,
#        26.74747475, 27.45454545, 28.16161616, 28.86868687, 29.57575758,
#        30.28282828, 30.98989899, 31.6969697 , 32.4040404 , 33.11111111,
#        33.81818182, 34.52525253, 35.23232323, 35.93939394, 36.64646465,
#        37.35353535, 38.06060606, 38.76767677, 39.47474747, 40.18181818,
#        40.88888889, 41.5959596 , 42.3030303 , 43.01010101, 43.71717172,
#        44.42424242, 45.13131313, 45.83838384, 46.54545455, 47.25252525,
#        47.95959596, 48.66666667, 49.37373737, 50.08080808, 50.78787879,
#        51.49494949, 52.2020202 , 52.90909091, 53.61616162, 54.32323232,
#        55.03030303, 55.73737374, 56.44444444, 57.15151515, 57.85858586,
#        58.56565657, 59.27272727, 59.97979798, 60.68686869, 61.39393939,
#        62.1010101 , 62.80808081, 63.51515152, 64.22222222, 64.92929293,
#        65.63636364, 66.34343434, 67.05050505, 67.75757576, 68.46464646,
#        69.17171717, 69.87878788, 70.58585859, 71.29292929, 72.        ])

# %%
#Calculate y=x**2 for the first 10 elements
first_10=x[0:10]
y=first_10**2
y
# Out:
# array([0.        , 0.01020304, 0.04081216, 0.09182736, 0.16324865,
#        0.25507601, 0.36730946, 0.49994898, 0.65299459, 0.82644628])

# %%
x[2]*x[2]
# Out:
# 0.040812162024283234

# %%
#Define a 100 equally spaced points using linspace. And then another 100 random points. And then add x and y together
x=np.linspace(0,10,100)

y=np.random.random(size=100)

# %%
#Add x and y together and save in z
z=x+y

# %%
#Calculate the sum of of x,y and z and tell me which one is the largest

# %%
# find the largest
largest=max(np.max(x),np.max(y),np.max(z))

print("largest:",largest)
# Out:
# largest: 10.86855445369655

# %%
z
# Out:
# array([ 0.40717248,  0.41366876,  0.74483901,  1.10201405,  0.59804458,
#         0.69536551,  1.53433645,  1.05350539,  1.49732466,  1.83105258,
#         1.72982629,  1.7303384 ,  1.74115165,  1.98941686,  1.82221554,
#         1.59388827,  1.87045669,  1.76229962,  2.01678081,  2.37258979,
#         2.56438153,  2.39307363,  3.20296027,  3.02176914,  3.17983303,
#         2.56013094,  3.11894873,  2.81817435,  3.36566662,  3.20683734,
#         3.8815425 ,  3.36024127,  3.35696635,  4.22768991,  3.89815298,
#         3.56152093,  4.53107002,  3.97529467,  4.32954128,  4.83328099,
#         4.32664485,  4.37658908,  5.06734356,  4.46012267,  4.66089485,
#         5.33996164,  4.94803935,  5.39547125,  5.24266058,  5.41134603,
#         5.68848462,  5.96080744,  5.90586392,  6.24135451,  5.67770046,
#         6.03763939,  6.11422276,  6.29942818,  5.93453282,  6.45106345,
#         6.54134854,  6.20615433,  6.93279264,  6.84998563,  7.20606178,
#         7.44491049,  7.05183019,  6.91693479,  7.19066769,  7.38442657,
#         7.54365961,  7.8501707 ,  7.881655  ,  7.95986154,  8.15426172,
#         7.77558127,  8.38370245,  7.91678628,  8.00076006,  8.59229789,
#         8.76799733,  9.15245094,  8.48930663,  9.36518985,  8.89955737,
#         9.43698116,  9.67638791,  9.22411768,  9.06901493,  9.96721924,
#         9.14425192,  9.82169868,  9.54283092,  9.57799294, 10.46482891,
#        10.31109278, 10.20758347,  9.79887401, 10.86855445, 10.30382232])

# %%
print(x.sum())
print(y.sum())
print(z.sum())
# Out:
# 500.0
# 49.3071379114735
# 549.3071379114734
