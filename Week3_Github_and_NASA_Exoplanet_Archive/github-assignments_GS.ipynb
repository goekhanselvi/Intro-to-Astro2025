# %%
mkdir Documents/intro-to-astro2025-clone #make a folder

# %%
cd Documents/intro-to-astro2025 #get in

# %%
git status # after doing changes check status

# %%
git add. # add changes

# %%
git commit -m "assigments"  #add

# %%
git pus origin main # push

# %%
https://github.com/goekhanselvi/Intro-to-Astro2025/commits/main/       # share the link
